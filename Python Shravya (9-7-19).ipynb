# %% [markdown]
# # Data Structures
# # python data strustures
# # lists
# # Dictionaries
# .Basic program sets on data structures
# .Advanced problem set
# .Conctact application
# # Data structures
# . To store data search,sort

# %%
lst=[1,8,16,9,2]
print(lst) # Access the entire lst
print(lst[0]) # Access first item
print(lst[1]) # Access the second item
print(lst[-1]) # Access the last item
print(lst[-2]) # Access second item from last
print(lst[1:]) # Access the lst except first
print(lst[1:4])# Access the lst except first and last
# Out:
# [1, 8, 16, 9, 2]
# 1
# 8
# 2
# 9
# [8, 16, 9, 2]
# [8, 16, 9]

# %%
# udate the list item values using index
li = ["Gitam","python",2000,2001]
print(li)
li[2]=2019
print(li)
# Out:
# ['Gitam', 'python', 2000, 2001]
# ['Gitam', 'python', 2019, 2001]

# %%
# Basic list operators
lst1=[1,9,6,18,2]
print(len(lst1)) # len of list
print(lst1 * 2) # Repetation
print(lst1 * 3)
print(2 in lst1)
print(23 in lst1)
print(18 in lst1)
print(1,9,2 in lst1)
# Access the items in lst using iteration
for x in range(len(lst1)):
    print(lst1[x],end=' ')
# Out:
# 5
# [1, 9, 6, 18, 2, 1, 9, 6, 18, 2]
# [1, 9, 6, 18, 2, 1, 9, 6, 18, 2, 1, 9, 6, 18, 2]
# True
# False
# True
# 1 9 True
# 1 9 6 18 2

# %%
# Funcions of lst 
lst1
print(min(lst1)) # minimum in list
print(max(lst1)) # maximum in lst
print(sum(lst1)) # sum of lst
print(sum(lst1[1::2])/len(lst1[1::2])) # Average of all items in lst
# Out:
# 1
# 18
# 36
# 13.5

# %%
lst1
lst1.append(24) # Adding a new element at end of lst
lst1
lst1.insert(2,56) # Adding elements into particuar index
lst1
lst1.count(18) # return the value how many times the object repeated
lst1.index(56)
lst1.sort() # it's sort the lstin ascending order
lst1
lst1.pop() # it's sort the lstin descending order
lst2 = [121,21,42]
lst1.extend(lst2) # merge lst2 in lst 1
lst1
# Out:
# [1, 2, 6, 9, 18, 24, 121, 21, 42]

# %%
li1=[1,9,8,2,6,3]
(li1[1:-1])
(li1[1:-2])
(li1[1:])
(li1[:-2])
li2=[4,5,7]
li1.extend(li2)
(li1[4])
# Out:
# 6

# %%
# function to find second large item list
# input : [1,2,3,5,7,0]
# output :[5]
def secondlarge(lst):
    lst.sort()
    return lst[-2]
def genericlarge(lst,n):
    lst.sort() 
    return lst[-n]
lst=[1,2,3,5,7,0]
genericlarge(lst,4)
# Out:
# 2

# %%
# Function to find least element
def secondleast(lst):
    lst.sort()
    return lst[-2]
def genericleast(lst,n):
    lst.sort() 
    return lst[n-1]
lst=[1,2,3,5,7,0]
genericleast(lst,4)
# Out:
# 3

# %%
# function to search data in list
# search is foundreturn index if not found return -1
def linearsearch(li,taritem):
    for x in range (len(li)):
        if li[x]==taritem:
            return x
        return -1
    li=[1,19,6,2,8,18,3]
linearsearch(li,1)
# Out:
# -1

# %%
# function 
# Input: [1,5,9,6,5,15,1,2,5],key=5 # duplicate
# Output:1 4 8
def linearsearch2(li,taritem):
    for x in range (len(li)):
        if li[x] == taritem:
            print(x,end=" ")
    return 
li = [1,5,9,6,5,15,1,2,5]
linearsearch2(li,5) #1 4 8
# Out:
# 1 4 8

# %%
# Function
# Input : List
# Output : seq of characters
# Test case
# [1,5,9,6,5,15,1,2,5],tar=5 -- !! !!!!! !!!!!!!!!
def linearsearch3(li,taritem):
    for x in range (len(li)):
        if li[x] == taritem:
            j=0
            while j!=x+1:
                 print("!",end=" ")
            j=j+1
            print(end=" ")
    return
li=[1,5,9,6,5,15,1,2,5]
linearsearch3(li,5) # !! !!!!! !!!!!!!!
# Out:
# ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! 
# ...

# %%
# Function 
# Input : list
# output : formatted
# test: 
# [12,2,45,9,18,15,36] -- 60
# A list is perfectly multiple of 3 and 5
def linearsearch4(li):
    sum=0
    for x in range(len(li)):
        if li[x]%3==0 and li[x]%5==0:
            sum+=li[x] 
    return sum
li=[12,2,45,9,18,15,36]
linearsearch4(li) # 60
# Out:
# 60

# %%
# Function 
# Input : list
# output : formatted
# test case: 
# [1,2,3,4,5] -- [1,3,8,15,5]
# [6,5,2,8,2] -- [6,12,40,4,2]
def linearsearch5(li):
    for x in range(len(li)):
        if x==0 or x == len(li) - 1:
        print(li[x],end=" ")
    else :
        print(li[x-1]*li[x+1],end=" ")
    return
li=[1,2,3,4,5] 
linearsearch5(li) # [1,3,8,15,5]
# Out:
#   File "<ipython-input-16-1047cfb41ca2>", line 10
#     print(li[x],end=" ")
#         ^
# IndentationError: expected an indented block

# %% [markdown]
# # 1.Print first and last asitis because first does not have previous and last doesnot have next
# # 2.need to multiply previous and next

# %%
# Function 
# [1,6,9,4,16,19,22] -- 1 9 19 22
def linearsearch6(li):
    for x in range(len(li)):
        if x == 0 or x == len(li) - 1:
             print(li[x],end=" ")
        elif li[x-1] % 2 == 0 and li[x+1] % 2 == 0:
                print(li[x],end=" ")
    return
li = [1,6,9,4,16,19,22]
linearsearch6(li) # 1,9,19,22
# Out:
# 1 9 19 22

# %% [markdown]
# Input as number
# output aslist

# %%
# Function for conversation-Number to list
# Test cases:
# 14569 -- [1,4,5,6,9]
# 1990 -- [1,9,9,0]
def numberlistconversion(n):
    li=[]
    while n != 0:
        r=n % 10
        li.append(r)
        n = n // 10
    li.reverse()
    return li
numberlistconversion(14569)#[1,4,5,6,9]
# Out:
# [1, 4, 5, 6, 9]

# %%
# Function to count accurances of a character in string
# "python programing", p ->2
# "python programing", m ->2
def countcharoccurances(s,c):
    cnt=0
    for ch in s:
        if ch == c:
            cnt += 1
    return cnt
countcharoccurances("python programing",'m')
# Out:
# 1

# %%
# Function to convert string to list
# Test code
# "1 2 3 4 5 6" -- [1,2,3,4,5,6]
def strinttolistconversion(s):
    li = s.split()
    numberslist = []
    for i in li:
        numberslist.append(int(i))
    return numberslist
s = "1 2 3 4 5 6"
strinttolistconversion(s) # [1,2,3,4,5,6]
# Out:
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# ### Sorting Algorithms :
# .All sorting algorithms make list into ascending order
#  -Bubble sort
#  -selection sort
#  -Insrtion sort

# %%
# Function to represent the bubble sort
def bubblesort(li):
    for i in range(len(li)):
        for j in range(len(li)-1):
            if li[j] > li[j+1] :
                li[j],li[j+1] = li[j+1],li[j]
    return li
li = [19,1,25,6,18,3]
bubblesort(li)
# Out:
# [1, 3, 6, 18, 19, 25]

# %%
def search(arr, x):
    for i in range(len(arr)):
        if arr[i] ==x:
return -1
# Out:
#   File "<ipython-input-3-4d6f213b3192>", line 4
#     return -1
#              ^
# IndentationError: expected an indented block
